# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
from bs4 import BeautifulSoup

# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Extract all of the <a> tags with the class "link"
a_tags = soup.find_all('<img>', class_='https://www.buzzfeed.com')

# Print the contents of the <a> tags
for a in a_tags:
    print(a.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 from bs4 import BeautifulSoup
#       3 # Parse the HTML
# ----> 4 soup = BeautifulSoup(html, 'html.parser')
#       6 # Extract all of the <a> tags with the class "link"
#       7 a_tags = soup.find_all('<img>', class_='https://www.buzzfeed.com')
#
# NameError: name 'html' is not defined

# %%
from bs4 import BeautifulSoup

# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Extract all of the <a> tags with the class "link"
a_tags = soup.find_all('img', class_='https://www.buzzfeed.com/in')

# Print the contents of the <a> tags
for a in a_tags:
    print(a.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       1 from bs4 import BeautifulSoup
#       3 # Parse the HTML
# ----> 4 soup = BeautifulSoup(html, 'html.parser')
#       6 # Extract all of the <a> tags with the class "link"
#       7 a_tags = soup.find_all('img', class_='https://www.buzzfeed.com/in')
#
# NameError: name 'html' is not defined

# %%
from bs4 import BeautifulSoup

# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Extract all of the <a> tags with the class "link"
img_tags = soup.find_all('img', class_='https://www.buzzfeed.com/in')

# Print the contents of the <a> tags
for img in img_tags:
    print(img.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       1 from bs4 import BeautifulSoup
#       3 # Parse the HTML
# ----> 4 soup = BeautifulSoup(html, 'html.parser')
#       6 # Extract all of the <a> tags with the class "link"
#       7 img_tags = soup.find_all('img', class_='https://www.buzzfeed.com/in')
#
# NameError: name 'html' is not defined

# %%
from bs4 import BeautifulSoup

# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Extract all of the <a> tags with the class "link"
a_tags = soup.find_all('a', class_='https://www.buzzfeed.com/in')

# Print the contents of the <a> tags
for a in a_tags:
    print(a.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 4>()
#       1 from bs4 import BeautifulSoup
#       3 # Parse the HTML
# ----> 4 soup = BeautifulSoup(html, 'html.parser')
#       6 # Extract all of the <a> tags with the class "link"
#       7 a_tags = soup.find_all('a', class_='https://www.buzzfeed.com/in')
#
# NameError: name 'html' is not defined

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.buzzfeed.com/in')
html = response.text
    
# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Extract all of the <p> tags
p_tags = soup.find_all('p')

# Print the contents of the <p> tags
for p in p_tags:
    print(p.text)
# Out:
# Brb, playing Pasoori for the 300th time.
# Yes, more popular than you in high school.
# We have newsletters to help you stay in the loop AND newsletters to help you forget! Try one today!
# What is this special deal men in the movies have with God?
# Woh din bhi kya din the!
# If this quiz says that you eat too much achaar, it's safe to assume that you're in a pickle.
# I can do this all day!
# We really leaned into make our kitchens more efficient this year.
# "Baby, baby, baby, oh"
# Sorry but Khichdi is super overrated!
# BuzzFeed Video
# DJ wale babu inka gaana chala do.
# It's simple! Look = Average and Lewk = Bomb AF. You decide.
# "O Twitter, o Twitter, tumne inn memes ko janam diya, sabse achcha karam kiya."
# TIL that my playlist is stuck in 2012.
# What do you mean that's not Deepika in 144p?
# Remember "surprise tests"?
# Tbh, I just wanna eat everything mentioned in here.
# So, where are we going?
# ...

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.buzzfeed.com/in')
html = response.text
    
# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Extract all of the <p> tags
p_tags = soup.find_all('img')

# Print the contents of the <p> tags
for p in p_tags:
    print(p.text)
# Out:
# 21 Kitchen Appliances That Were A Hit Amongst BuzzFeed India Readers In 2021
# We really leaned into make our kitchens more efficient this year.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Play
#
#
# Video duration 11:43 minutes
#
#
#         Watch
#
#
#
#
# BuzzFeed Video
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Play
#
#
# Video duration 10:23 minutes
#
#
#         Watch
#
#
#
#
# BuzzFeed Video
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Play
#
#
# Video duration 9:30 minutes
#
#
#         Watch
#
#
#
#
# BuzzFeed Video
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Play
#
#
# Video duration 8:16 minutes
#
#
#         Watch
#
#
#
#
# BuzzFeed Video
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Play
#
#
# Video duration 11:22 minutes
#
#
#         Watch
#
#
#
#
# BuzzFeed Video
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Play
#
#
# Video duration 12:27 minutes
#
#
#         Watch
#
#
#
#
# BuzzFeed Video
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Make an HTTP request to the website and retrieve the HTML content
response = requests.get('https://www.toyota.com/')
html = response.text

# Parse the HTML using Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# Extract the duration of each video on the website
video_durations = []
for video in soup.find_all('video'):
    duration = video['duration']
    video_durations.append(duration)

# Calculate the average duration
total_duration = sum(video_durations)
num_videos = len(video_durations)
average_duration = total_duration / num_videos

print(f'Average video duration: {average_duration:.2f} seconds')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 13>()
#      12 video_durations = []
#      13 for video in soup.find_all('video'):
# ---> 14     duration = video['duration']
#      15     video_durations.append(duration)
#      17 # Calculate the average duration
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py:1519, in Tag.__getitem__(self, key)
#    1516 def __getitem__(self, key):
#    1517     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518     and throws an exception if it's not there."""
# -> 1519     return self.attrs[key]
#
# KeyError: 'duration'

# %%
import requests
from bs4 import BeautifulSoup

# Make an HTTP request to the website and retrieve the HTML content
response = requests.get('https://www.buzzfeed.com/in')
html = response.text

# Parse the HTML using Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# Extract the <img> tags from the HTML
img_tags = soup.find_all('img')

# Count the number of <img> tags
num_images = len(img_tags)

print(f'Total number of images on the website: {num_images}')
# Out:
# Total number of images on the website: 205

# %%
import requests
from bs4 import BeautifulSoup

# Make an HTTP request to the website and retrieve the HTML content
response = requests.get('https://www.buzzfeed.com/in')
html = response.text

# Parse the HTML using Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# Extract the src attribute of each <img> element on the page
img_urls = []
for img in soup.find_all('img'):
    src = img['src']
    img_urls.append(src)

# Count the number of images with a size greater than 25KB
count = 0
for url in img_urls:
    # Make another HTTP request to the image URL and retrieve its size
    response = requests.get(url)
    size = len(response.content)

    # Increment the count if the size is greater than 25KB
    if size > 25000:
        count += 1

print(f'Total number of images with size > 25KB: {count}')
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Input In [18], in <cell line: 19>()
#      18 count = 0
#      19 for url in img_urls:
#      20     # Make another HTTP request to the image URL and retrieve its size
# ---> 21     response = requests.get(url)
#      22     size = len(response.content)
#      24     # Increment the count if the size is greater than 25KB
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Make an HTTP request to the website and retrieve the HTML content
response = requests.get('https://www.buzzfeed.com/in')
html = response.text

# Parse the HTML using Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# Extract the <img> tags from the HTML
img_tags = soup.find_all('img')

# Count the number of <img> tags
num_imgs = len(img_tags)

print(f'Total number of images: {num_imgs}')
# Out:
# Total number of images: 205

# %%
import scrapy
import logging

class HeaderSpider(scrapy.Spider):
    name = "header_spider"
    start_urls = ['https://www.buzzfeed.com/in']

    custom_settings = {
        'LOG_LEVEL': logging.DEBUG,  # Set the logging level to DEBUG
        'LOG_FORMAT': '%(levelname)s: %(message)s'  # Set the logging format
    }

    def parse(self, response):
        # Extract all the header data from the response
        headers = response.headers

        # Convert the headers to a dictionary
        headers_dict = dict(headers)

        # Store the header data in an array
        header_data = []
        for key, value in headers_dict.items():
            header_data.append(f"{key}: {value}")

        # Print the header data
        self.log(header_data, level=logging.DEBUG)

        # Extract the <img> tags from the HTML
        img_tags = response.css('img')

        # Count the number of <img> tags
        num_images = len(img_tags)

        # Count the number of images above 15KB
        num_large_images = 0
        for img_tag in img_tags:
            img_size = img_tag.attrib.get('size')
            if img_size is not None and int(img_size) > 15000:  # Check if image size is greater than 15KB
                num_large_images += 1

        print(f'Total number of images on the website: {num_images}')
        print(f'Total number of images above 15KB: {num_large_images}')

# %%
import requests
from bs4 import BeautifulSoup

# Make an HTTP request to the website and retrieve the HTML content
response = requests.get('https://www.buzzfeed.com/in')
html = response.text

# Parse the HTML using Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# Extract the <img> tags from the HTML
img_tags = soup.find_all('img')

# Count the number of images above 25KB in size
num_imgs = 0
for img in img_tags:
    # Get the image URL from the <img> tag
    img_url = img['src']

    # Make an HTTP request to download the image
    img_response = requests.get(img_url)

    # Check the image size and increment the count if it's above 25KB
    if len(img_response.content) > 25000:
        num_imgs += 1

print(f'Total number of images above 25KB: {num_imgs}')
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Input In [21], in <cell line: 16>()
#      18 img_url = img['src']
#      20 # Make an HTTP request to download the image
# ---> 21 img_response = requests.get(img_url)
#      23 # Check the image size and increment the count if it's above 25KB
#      24 if len(img_response.content) > 25000:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
# ...

# %%
from bs4 import BeautifulSoup
import requests

# Set the URL of the website to search
url = "https://www.businessworld.in/video/BW-Marketing-Whitebook-Summit-2022-VIP-Clothing-s-Sunil-Pathare-Takes-A-Deep-Dive-Into-The-Metaverse-/06-09-2022-4006/"

# Send a GET request to the URL
response = requests.get(url)

# Parse the response HTML using Beautiful Soup
soup = BeautifulSoup(response.text, "html.parser")

# Find all the <video> tags on the website
video_tags = soup.find_all("video")

# Count the number of <video> tags
num_videos = len(video_tags)

# Print the total number of videos on the website
print(f"Total number of videos: {num_videos}")
# Out:
# Total number of videos: 0

# %%
from bs4 import BeautifulSoup
import requests

# Set the URL of the website to search
url = "https://localnews8.com/"

# Send a GET request to the URL
response = requests.get(url)

# Parse the response HTML using Beautiful Soup
soup = BeautifulSoup(response.text, "html.parser")

# Find all the <img> tags on the website
img_tags = soup.find_all("img")

# Count the number of <img> tags
num_img = len(img_tags)

# Print the total number of img on the website
print(f"Total number of img: {num_img}")
# Out:
# Total number of img: 67

# %%
from bs4 import BeautifulSoup
import requests

# Set the URL of the website to search
url = "https://www.qq.com/"

# Send a GET request to the URL
response = requests.get(url)

# Parse the response HTML using Beautiful Soup
soup = BeautifulSoup(response.text, "html.parser")

# Find all the <video> tags with ".mp4" in the src attribute
video_links = soup.find_all("video", src=lambda src: src and ".mp4" in src)

# Count the number of <video> tags with ".mp4" in the src attribute
num_links = len(video_links)


# Print the total number of links containing ".mp4" on the website
print(f"Total number of links containing '.mp4': {num_links}")
# Out:
# Total number of links containing '.mp4': 0

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# Read the Excel file containing the URLs
df = pd.read_excel("/Users/rentsher/Desktop/Gumlet/urls.xlsx")

# Iterate over the rows in the dataframe
for index, row in df.iterrows():
    # Get the URL from the first column
    url = row["A"]
    
    # Download the HTML content of the website
    html = requests.get(url).text
    
    # Parse the HTML using Beautiful Soup
    soup = BeautifulSoup(html, "html.parser")
    
    # Extract all link tags from the page
    link_tags = soup.find_all("a")
    
    # Count the number of link tags
    link_count = len(link_tags)
    
    # Save the link count to the second column
    df.loc[index, "B"] = link_count

# Save the dataframe to an Excel file
df.to_excel("/Users/rentsher/Desktop/Gumlet/results.xlsx")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %%
# Import the libraries and open the Excel file
from bs4 import BeautifulSoup
import requests
import openpyxl

wb = openpyxl.load_workbook('/Users/rentsher/Desktop/Gumlet/Traffic_test.xlsx')
sheet = wb['Sheet1']

for row in sheet.iter_rows(min_row=2, max_col=2):
  # Get the URL from cell A and the row number
  url = row[0].value
  row_number = row[0].row

  # Send an HTTP request to the website and parse the HTML content
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')

  # Find the element with the data-testid attribute you are interested in
  element = soup.find(attrs={"data-testid": "siteheader_monthlyvisits"})

  # Extract the data you are interested in from the element
  if element:
  # Extract the data you are interested in from the element
  data = element.text
else:
  data = ""

  # Write the data to cell B of the current row
  sheet.cell(row=row_number, column=2).value = data
    
# Save the changes to the Excel file
wb.save('/Users/rentsher/Desktop/Gumlet/Traffic_test.xlsx')
# Out:
#   Input In [57]
#     data = element.text
#     ^
# IndentationError: expected an indented block

# %%
from bs4 import BeautifulSoup
import requests
import openpyxl

# %%
pip install beautifulsoup4 openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the libraries
from bs4 import BeautifulSoup
import requests
import openpyxl

# Open the Excel file and select the sheet you want to work with
wb = openpyxl.load_workbook('/Users/rentsher/Desktop/Gumlet/Traffic_test.xlsx')
sheet = wb['Sheet1']

# Iterate over the rows in the sheet and fetch the data for each row
for row in sheet.iter_rows(min_row=2, max_col=2):
  # Get the URL from cell A and the row number
  url = row[0].value
  row_number = row[0].row

  # Send an HTTP request to the website and parse the HTML content
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')

  # Find the element with the data-testid attribute you are interested in
  element = soup.find(attrs={"data-testid": "siteheader_monthlyvisits"})

  # Extract the data you are interested in from the element
  if element:
    data = element.text
  else:
    data = ""

  # Write the data to cell B of the current row
  sheet.cell(row=row_number, column=2).value = data

# Save the changes to the Excel file
wb.save('/Users/rentsher/Desktop/Gumlet/Traffic_test.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [58], in <cell line: 11>()
#      14 row_number = row[0].row
#      16 # Send an HTTP request to the website and parse the HTML content
# ---> 17 response = requests.get(url)
#      18 soup = BeautifulSoup(response.text, 'html.parser')
#      20 # Find the element with the data-testid attribute you are interested in
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
# ...

# %%
pip install tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the tqdm library
from tqdm import tqdm

# Open the Excel file and select the sheet you want to work with
wb = openpyxl.load_workbook('/Users/rentsher/Desktop/Gumlet/Traffic_test.xlsx')
sheet = wb['Sheet1']

# Get the total number of rows in the sheet
num_rows = sheet.max_row

# Initialize a counter variable to keep track of the number of rows processed
counter = 0

# Iterate over the rows in the sheet and fetch the data for each row
for row in tqdm(sheet.iter_rows(min_row=2, max_col=2), total=num_rows - 1):
  # Get the URL from cell A and the row number
  url = row[0].value
  row_number = row[0].row

  # Send an HTTP request to the website and parse the HTML content
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')

  # Find the element with the data-testid attribute you are interested in
  element = soup.find(attrs={"data-testid": "siteheader_monthlyvisits"})

  # Extract the data you are interested in from the element
  if element:
    data = element.text
  else:
    data = ""

  # Write the data to cell B of the current row
  sheet.cell(row=row_number, column=2).value = data

  # Increment the counter variable
  counter += 1

# Save the changes to the Excel file
wb.save('/Users/rentsher/Desktop/Gumlet/Traffic_test.xlsx')

# Print the percentage of data fetched
print(f"{counter / num_rows * 100:.2f}% of data fetched")
# Out:
#   1%|█▏                                                                                                                                                               | 141/19802 [03:11<7:25:05,  1.36s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [60], in <cell line: 15>()
#      18 row_number = row[0].row
#      20 # Send an HTTP request to the website and parse the HTML content
# ---> 21 response = requests.get(url)
#      22 soup = BeautifulSoup(response.text, 'html.parser')
#      24 # Find the element with the data-testid attribute you are interested in
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
# ...

# %%
import scrapy
import logging

class HeaderSpider(scrapy.Spider):
    name = "header_spider"
    start_urls = ['https://www.buzzfeed.com/in']

    custom_settings = {
        'LOG_LEVEL': logging.DEBUG,  # Set the logging level to DEBUG
        'LOG_FORMAT': '%(levelname)s: %(message)s'  # Set the logging format
    }

    def parse(self, response):
        # Extract all the header data from the response
        headers = response.headers

        # Convert the headers to a dictionary
        headers_dict = dict(headers)

        # Store the header data in an array
        header_data = []
        for key, value in headers_dict.items():
            header_data.append(f"{key}: {value}")

        # Print the header data
        self.log(header_data, level=logging.DEBUG)

        # Extract the <img> tags from the HTML
        img_tags = response.css('img')

        # Count the number of <img> tags
        num_images = len(img_tags)

        # Count the number of images above 15KB
        num_large_images = 0
        for img_tag in img_tags:
            img_size = img_tag.attrib.get('size')
            if img_size is not None and int(img_size) > 15000:  # Check if image size is greater than 15KB
                num_large_images += 1

        print(f'Total number of images on the website: {num_images}')
        print(f'Total number of images above 15KB: {num_large_images}')

# %%
pip install selenium
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Input In [1], in <cell line: 22>()
#      22 while(page<=5):
#      24     col=0
# ---> 25     browser = webdriver.Firefox()
#      26     browser.get("https://www.justdial.com/Gurugram/builders/page-"+str(page))
#      27     name_element = browser.find_elements_by_xpath("//h2[@class='store-name']")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/firefox/webdriver.py:201, in WebDriver.__init__(self, firefox_profile, firefox_binary, capabilities, proxy, executable_path, options, service_log_path, service_args, service, desired_capabilities, log_path, keep_alive)
#     196 self.service.start()
#     198 executor = FirefoxRemoteConnection(
#     199     remote_server_addr=self.service.service_url, ignore_proxy=options._ignore_local_proxy
#     200 )
# ...

# %%
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('https://www.justdial.com/Bangalore/Restaurants-in-Koramangala/nct-10408936', help='Enter the url you want to scrape')
parser.add_argument('--file', help='Specify the file name', default="export.csv")
args = parser.parse_args()

from bs4 import BeautifulSoup
import urllib
import urllib.request
import requests
import csv
import os
import time


def innerHTML(element):
    return element.decode_contents(formatter="html")

def get_name(body):
	return body.find('span', {'class':'jcn'}).a.attrs['title']

def which_digit(html):
    mappingDict={'icon-ji':9,
                'icon-dc':'+',
                'icon-fe':'(',
                'icon-hg':')',
                'icon-ba':'-',
                'icon-lk':8,
                'icon-nm':7,
                'icon-po':6,
                'icon-rq':5,
                'icon-ts':4,
                'icon-vu':3,
                'icon-wx':2,
                'icon-yz':1,
                'icon-acb':0,
                }
    return mappingDict.get(html,'')

def get_phone_number(body):
    i=0
    phoneNo = "No Number!"
    try:
            
        for item in body.find('p',{'class':'contact-info'}):
            i+=1
            if(i==2):
                phoneNo=''
                try:
                    for element in item.find_all(class_=True):
                        classes = []
                        classes.extend(element["class"])
                        phoneNo+=str((which_digit(classes[1])))
                except:
                    pass
    except:
        pass
    body = body['data-href']
    soup = BeautifulSoup(body, 'html.parser')
    for a in soup.find_all('a', {"id":"whatsapptriggeer"} ):
        # print (a)
        phoneNo = str(a['href'][-10:])


    return phoneNo


def get_rating(body):
	rating = 0.0
	text = body.find('span', {'class':'star_m'})
	if text is not None:
		for item in text:
			rating += float(item['class'][0][1:])/10

	return rating

def get_rating_count(body):
	text = body.find('span', {'class':'rt_count'}).string

	# Get only digits
	rating_count =''.join(i for i in text if i.isdigit())
	return rating_count

def get_address(body):
	return body.find('span', {'class':'mrehover'}).text.strip()

def get_location(body):
	text = body.find('a', {'class':'rsmap'})
	if text == None:
		return
	text_list = text['onclick'].split(",")
	
	latitutde = text_list[3].strip().replace("'", "")
	longitude = text_list[4].strip().replace("'", "")
	
	return latitutde + ", " + longitude

page_number = 1
service_count = 1


fields = ['Name', 'Phone', 'Rating', 'Rating Count', 'Address', 'Location']
out_file = open(args.file,'w')
csvwriter = csv.DictWriter(out_file, delimiter=',', fieldnames=fields)

# Write fields first
#csvwriter.writerow(dict((fn,fn) for fn in fields))
while True:
	time.sleep(2)
	# Check if reached end of result
	if page_number > 50:
		break

	url="%s/page-%s" % (args.url, page_number)
	print(url)
	req = urllib.request.Request(url, headers={'User-Agent' : "Mozilla/5.0 (Windows NT 6.1; Win64; x64)"}) 
	page = urllib.request.urlopen( req )
	# page=urllib2.urlopen(url)

	soup = BeautifulSoup(page.read(), "html.parser")
	services = soup.find_all('li', {'class': 'cntanr'})

	# Iterate through the 10 results in the page
	for service_html in services:

		# Parse HTML to fetch data     
		dict_service = {}
		name = get_name(service_html)
		print(name);
		phone = get_phone_number(service_html)
		rating = get_rating(service_html)
		count = get_rating_count(service_html)
		address = get_address(service_html)
		location = get_location(service_html)
		if name != None:
			dict_service['Name'] = name
		if phone != None:
			print('getting phone number')
			dict_service['Phone'] = '\'' + phone
		if rating != None:
			dict_service['Rating'] = rating
		if count != None:
			dict_service['Rating Count'] = count
		if address != None:
			dict_service['Address'] = address
		if location != None:
			dict_service['Address'] = location

		# Write row to CSV
		csvwriter.writerow(dict_service)

		print("#" + str(service_count) + " " , dict_service)
		service_count += 1

	page_number += 1

out_file.close()
# Out:
# usage: ipykernel_launcher.py [-h] [--url URL] [--file FILE]
# ipykernel_launcher.py: error: unrecognized arguments: -f /Users/rentsher/Library/Jupyter/runtime/kernel-5cce41dd-cc99-4855-95ee-8a1b20a47dd8.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import concurrent.futures
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# Load CSV file
csv_path = 'test.csv'  # Change the input file path
df = pd.read_csv(csv_path)

# Create new columns for related topics and category values
df['Related Topics'] = ''
df['Category Values'] = ''

# Create a progress bar using tqdm
pbar = tqdm(total=len(df), desc="Fetching data")

# Create a new DataFrame for Unique Similar Sites
unique_similar_sites_df = pd.DataFrame(columns=['Domain', 'Unique Similar Site'])

# Set to keep track of visited domains across all depths
visited_domains = set()

# Function to fetch unique similar sites for a given domain recursively with 5 depths
def fetch_unique_similar_sites_recursive(domain, depth=1):  # Start from depth 1
    global unique_similar_sites_df
    global visited_domains

    if depth > 5 or domain in visited_domains:
        return

    print(f"Fetching unique similar sites for {domain} (Depth: {depth})")

    source_url = f'https://www.similarsites.com/site/{domain}'

    try:
        # Make a request to the source URL with a custom user-agent
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
        r = requests.get(source_url, headers=headers)
        r.raise_for_status()  # Raise HTTPError for bad responses
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {domain}: {e}")
        return None

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(r.text, 'html.parser')

    # Find Unique Similar Sites
    similar_sites_divs = soup.find_all('div', class_='SimilarSitesCard__Domain-zq2ozc-4 kuvZIX')
    similar_sites = [site.text.strip() for site in similar_sites_divs]

    # Remove duplicate Similar Sites and already visited domains using set
    unique_similar_sites = set(similar_sites) - visited_domains

    # Save unique similar sites for the current domain
    for unique_site in unique_similar_sites:
        unique_similar_sites_df = pd.concat([unique_similar_sites_df, pd.DataFrame({'Domain': [domain], 'Unique Similar Site': [unique_site]})], ignore_index=True)

        # Mark the domain as visited to avoid processing it again
        visited_domains.add(unique_site)

        # Fetch unique similar sites recursively for the new domain
        fetch_unique_similar_sites_recursive(unique_site, depth=depth + 1)

    print(f"Finished fetching unique similar sites for {domain} (Depth: {depth})")

# Use ThreadPoolExecutor for concurrent execution
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit tasks for each domain
    futures = [executor.submit(fetch_unique_similar_sites_recursive, row['Domain']) for _, row in df.iterrows()]

    # Process results as they complete
    for future in concurrent.futures.as_completed(futures):
        result = future.result()
        if result:
            pbar.update(1)

# Close the progress bar
pbar.close()

# Save Unique Similar Sites DataFrame to a new CSV file
unique_similar_sites_output_csv_path = '/Users/rentsher/Desktop/Unique_Similar_Sites.csv'  # Adjust the output file path
unique_similar_sites_df.to_csv(unique_similar_sites_output_csv_path, index=False)
# Out:
# Fetching data:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching unique similar sites for https://yourstory.com/companies/townhallco (Depth: 1)
# Fetching data:   0%|          | 0/1 [00:01<?, ?it/s]
# Error fetching data for https://yourstory.com/companies/townhallco: 404 Client Error: Not Found for url: https://www.similarsites.com/site/https://yourstory.com/companies/townhallco
