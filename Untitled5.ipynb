# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Make an HTTP request to the website and retrieve the HTML content
response = requests.get('https://www.buzzfeed.com/in')
html = response.text

# Parse the HTML using Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# Extract all the <a> tags from the HTML
a_tags = soup.find_all('a')

# Initialize a counter for images above 10KB and counter for retrieved images
num_images_above_10kb = 0
num_retrieved_images = 0

# Loop through each <a> tag and extract the href link
for a_tag in a_tags:
    if num_retrieved_images >= 5:
        break  # Break out of the loop once desired count is reached
    
    page_url = a_tag.get('href')
    # Join the href link with the base URL
    page_url = urljoin(response.url, page_url)
    print(f'Page URL: {page_url}')
    
    try:
        # Make an HTTP request to the page URL and retrieve the HTML content
        page_response = requests.get(page_url)
        page_html = page_response.text
        
        # Parse the HTML using Beautiful Soup for the page
        page_soup = BeautifulSoup(page_html, 'html.parser')
        
        # Extract all the <img> tags from the page HTML
        img_tags = page_soup.find_all('img')
        
        # Loop through each <img> tag and extract the image src link
        for img_tag in img_tags:
            if num_retrieved_images >= 5:
                break  # Break out of the loop once desired count is reached
            
            img_src = img_tag.get('src')
            # Join the image src link with the base URL
            img_url = urljoin(page_response.url, img_src)
            print(f'Image URL: {img_url}')
            
            try:
                # Make an HTTP request to the image URL and retrieve the headers
                img_response = requests.get(img_url)
                headers = img_response.headers
                
                # Convert headers to array format
                headers_array = []
                for key, value in headers.items():
                    headers_array.append({key: value})
                    
                print('Headers Data:')
                print(headers_array)
                
                # Check the size/weight of the image
                if len(img_response.content) > 10 * 1024:
                    num_images_above_10kb += 1
                    num_retrieved_images += 1
                    print(f'Size/Weight: {len(img_response.content)} bytes (above 10KB)')
                    
                    # Check if the desired count is reached
                    if num_retrieved_images >= 5:
                        print('5 images above 10KB retrieved. Exiting...')
                        break  # Break out of the loop once desired count is reached
                else:
                    print(f'Size/Weight: {len(img_response.content)} bytes')
                
                print('---')
                
            except requests.exceptions.RequestException as e:
                print(f'Error occurred while making request: {e}')
                print('Skipping this image.')
                print('---')

    except requests.exceptions.RequestException as e:
        print(f'Error occurred while making request: {e}')
        print('Skipping this page.')
        print('---')

print(f'Total number of images above 10KB: {num_images_above_10kb}')
# Out:
# Page URL: https://www.buzzfeed.com?origin=tb
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/2023-04/17/10/campaign_images/2eb4f357329a/31-hilarious-ramadan-memes-that-will-have-you-gas-3-1452-1681727536-0_dblwide.jpg?output-format=auto&output-quality=100
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '17772'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"19v52jdcKUsLM/1lEmTfj1G0UOuail4ts2+RdLpeO7c"'}, {'Fastly-Io-Info': 'ifsz=101823 idim=625x220 ifmt=jpeg ofsz=17772 odim=625x220 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': '1qi1CmYAg3QIZyT5mgBI/Hudq+r2LwSL1jYI84F7pVCVtXXSp2x7ipeCeeIClsuy/gNdE5Teb8ECN3toDgl/iA=='}, {'X-Amz-Replication-Status': 'COMPLETED'}, {'X-Amz-Request-Id': 'PB037MPWAT6Z0DVT'}, {'X-Amz-Server-Side-Encryption': 'AES256'}, {'X-Amz-Version-Id': '1BzSF42PbVuLresIS5eP7huSkpnb4mZe'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:17 GMT'}, {'Age': '491319'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kjyo7100161-IAD, cache-iad-kcgs7200095-IAD, cache-maa10248-MAA'}, {'X-Cache': 'MISS, HIT, HIT'}, {'X-Cache-Hits': '0, 2, 1'}, {'X-Timer': 'S1682319798.515194,VS0,VE1'}, {'Vary': 'X-Image-Format-Optimization'}]
# Size/Weight: 17772 bytes (above 10KB)
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/2021-11/10/9/campaign_images/baf7385716f8/22-wildly-popular-products-with-over-1000-positiv-2-3496-1636535127-6_dblbig.jpg?output-format=auto&output-quality=auto&resize=300:*;
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '13512'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"6qS4kRM52g1WLv+WBblRKZMfEjXdNsckERyAeWusD20"'}, {'Fastly-Io-Info': 'ifsz=346879 idim=625x415 ifmt=jpeg ofsz=13512 odim=300x199 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': '2Skyie38TgAtQRl1RnUO4D5R+GsyWtl/6mEoq9EnwQKIt6B0MSJJWwH9Odx/MjmDKYXj45h56aA='}, {'X-Amz-Replication-Status': 'COMPLETED'}, {'X-Amz-Request-Id': 'QDE8EF8E12XP6WYN'}, {'X-Amz-Storage-Class': 'STANDARD_IA'}, {'X-Amz-Version-Id': '.YrcN25rLpfatluhTV5dxUYLGEbkHsZN'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:17 GMT'}, {'Age': '1941303'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kjyo7100103-IAD, cache-iad-kjyo7100040-IAD, cache-maa10237-MAA'}, {'X-Cache': 'HIT, HIT, HIT'}, {'X-Cache-Hits': '1, 5, 1'}, {'X-Timer': 'S1682319798.570996,VS0,VE1'}, {'Vary': 'X-Image-Format-Optimization, X-Image-Quality-Optimization'}]
# Size/Weight: 13512 bytes (above 10KB)
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/user_images/UbSHFu93_large.jpg?output-format=jpg&crop=500%3A500%3B0%2C11?output-format=jpeg&output-quality=85&downsize=30:*
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '1392'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"KXmjpatlB8NCBiR0t2/FBTj8ru38aWfsOCyuGt6LCTE"'}, {'Fastly-Io-Info': 'ifsz=821290 idim=500x666 ifmt=png ofsz=1392 odim=30x30 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': 'BY64iAwSW5651OMjptOw9wHK37jZVUeMHIC2c4up/b55DTAaJR2xDvWUKguy/OYoTtRwxp2/CLg='}, {'X-Amz-Replication-Status': 'FAILED'}, {'X-Amz-Request-Id': 'MKBGJENN371T1XC3'}, {'X-Amz-Storage-Class': 'STANDARD_IA'}, {'X-Amz-Version-Id': 'Np9GYGcImXYpxFcrlSYEYAeHLtkrSgPb'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:17 GMT'}, {'Age': '2846630'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kjyo7100023-IAD, cache-iad-kjyo7100023-IAD, cache-maa10227-MAA'}, {'X-Cache': 'HIT, HIT, HIT'}, {'X-Cache-Hits': '1, 4059, 14'}, {'X-Timer': 'S1682319798.644059,VS0,VE0'}]
# Size/Weight: 1392 bytes
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/2018-10/5/15/tmp/buzzfeed-prod-web-04/tmp-name-2-22857-1538767328-13_dblbig.jpg?output-format=auto&output-quality=auto&resize=300:*
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '8356'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"FfK7K21OKcZ2SxYED/S1313WtMLaJBCZ3GdtyqXPzbQ"'}, {'Fastly-Io-Info': 'ifsz=203191 idim=625x415 ifmt=jpeg ofsz=8356 odim=300x199 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': 'OHHP/9XE0FTW3tLseQEDQqOALwPtNY+GndOJGIKaLbJ3SOXm4HmjQjPqu8Zm3vM2FRr5uRosFog='}, {'X-Amz-Replication-Status': 'COMPLETED'}, {'X-Amz-Request-Id': '6DWFGZB78ZNFD8P9'}, {'X-Amz-Storage-Class': 'STANDARD_IA'}, {'X-Amz-Version-Id': 'mCYWtgykdnd0KbjU2mUrbPfgy.lfrzGY'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:17 GMT'}, {'Age': '2816206'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kiad7000031-IAD, cache-iad-kiad7000031-IAD, cache-maa10250-MAA'}, {'X-Cache': 'HIT, HIT, HIT'}, {'X-Cache-Hits': '1, 177, 1'}, {'X-Timer': 'S1682319798.722210,VS0,VE1'}, {'Vary': 'X-Image-Format-Optimization, X-Image-Quality-Optimization'}]
# Size/Weight: 8356 bytes
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/2014-06/12/16/user_images/webdr04/buzzfeedpromotions-10918-1402603767-14_large.jpg?output-format=jpeg&output-quality=85&downsize=30:*
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '1409'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"9NBafRvqsJMhpfJTvI1gq8GJvWGlx+IfPFV9IAYfTKk"'}, {'Fastly-Io-Info': 'ifsz=3418 idim=70x70 ifmt=jpeg ofsz=1409 odim=30x30 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': 'RZVd6AHR9n2SJZMj+gZQXnc7VdO0Cz7Tfpgy5B9Urq0zRaCwKyo413wYA/WXTjYae2YtFxImmr4swRZOPCwYcw=='}, {'X-Amz-Request-Id': 'RGJMY412VARRM60W'}, {'X-Amz-Version-Id': 'null'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:17 GMT'}, {'Age': '5340441'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kcgs7200103-IAD, cache-iad-kcgs7200103-IAD, cache-maa10249-MAA'}, {'X-Cache': 'HIT, HIT, HIT'}, {'X-Cache-Hits': '1, 10060, 6'}, {'X-Timer': 'S1682319798.791993,VS0,VE0'}]
# Size/Weight: 1409 bytes
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/2023-04/4/20/tmp/4a58f883a7a0/tmp-name-3-1674-1680640095-0_dblbig.jpg?output-format=auto&output-quality=auto&resize=300:*;
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '10563'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"9YrrXTQAbBj8tu3NKXe7smdHGU0yFayPbHV46lXkVZ8"'}, {'Fastly-Io-Info': 'ifsz=290675 idim=625x415 ifmt=jpeg ofsz=10563 odim=300x199 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': 'HJwD/3A6D0aPiIHxLKam+dCW5TG3yffJ8/Xdk2nHL7ioPNmPlKY1jfLn28gAVIs/e/SaHDBOtJU='}, {'X-Amz-Replication-Status': 'COMPLETED'}, {'X-Amz-Request-Id': 'EX48GMT27B4BSWJE'}, {'X-Amz-Server-Side-Encryption': 'AES256'}, {'X-Amz-Version-Id': 'CkO6_vD8IIOTXQvebqlNitIqG6XMD3Fh'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:17 GMT'}, {'Age': '1263493'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kiad7000104-IAD, cache-iad-kjyo7100025-IAD, cache-maa10250-MAA'}, {'X-Cache': 'MISS, HIT, HIT'}, {'X-Cache-Hits': '0, 17, 1'}, {'X-Timer': 'S1682319798.864203,VS0,VE1'}, {'Vary': 'X-Image-Format-Optimization, X-Image-Quality-Optimization'}]
# Size/Weight: 10563 bytes (above 10KB)
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/user_images/-i46u7AEM_large.jpg?output-format=jpg&crop=333%3A334%3B50%2C8?output-format=jpeg&output-quality=85&downsize=30:*
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '1347'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"kg3mHhvXZ+hf2PdW8C4RFHbdR9s0koeR3coKCEnY9Lc"'}, {'Fastly-Io-Info': 'ifsz=657704 idim=500x502 ifmt=png ofsz=1347 odim=30x30 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': 'XN1Cu+licd/JpoItDzcUdme/4y0l1ak82pHvmT7/tvzaPzHPWzpQgaFFJA8nObpqVDOVehXu/so='}, {'X-Amz-Replication-Status': 'FAILED'}, {'X-Amz-Request-Id': '9PG5JFQBZ7PD4GJJ'}, {'X-Amz-Storage-Class': 'STANDARD_IA'}, {'X-Amz-Version-Id': 'O0S4R2Jo4rsTpx57pXPLhioeD3WytQ8g'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:17 GMT'}, {'Age': '4204911'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kiad7000064-IAD, cache-iad-kiad7000064-IAD, cache-maa10248-MAA'}, {'X-Cache': 'HIT, HIT, HIT'}, {'X-Cache-Hits': '1, 30771, 18'}, {'X-Timer': 'S1682319798.936467,VS0,VE0'}]
# Size/Weight: 1347 bytes
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/2023-04/8/17/campaign_images/5631475a2a0b/20-photos-that-will-simply-restore-your-faith-in--3-617-1680974088-1_dblbig.jpg?output-format=auto&output-quality=auto&resize=300:*;
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '17240'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"A3XsHScbQ8F69HP0y4PSY+IYJK/izzJXQ9Qu9iyccR0"'}, {'Fastly-Io-Info': 'ifsz=392016 idim=625x415 ifmt=jpeg ofsz=17240 odim=300x199 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': 'JZPmUfloVawsjxBxnQnUdzGsNUuvHJzxsn30+URG26ZzkJJ1p5Tpuvtqf9vkE1u4wjCGP6d7Njw='}, {'X-Amz-Replication-Status': 'COMPLETED'}, {'X-Amz-Request-Id': 'K5ZG5EQ86087XS65'}, {'X-Amz-Server-Side-Encryption': 'AES256'}, {'X-Amz-Version-Id': 'ohcRScTqLr3NH3YXXKnexMqIXDhn9eHN'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:18 GMT'}, {'Age': '1345622'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kcgs7200041-IAD, cache-iad-kjyo7100174-IAD, cache-maa10223-MAA'}, {'X-Cache': 'MISS, HIT, HIT'}, {'X-Cache-Hits': '0, 27, 1'}, {'X-Timer': 'S1682319798.020838,VS0,VE15'}, {'Vary': 'X-Image-Format-Optimization, X-Image-Quality-Optimization'}]
# Size/Weight: 17240 bytes (above 10KB)
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/user_images/-i46u7AEM_large.jpg?output-format=jpg&crop=333%3A334%3B50%2C8?output-format=jpeg&output-quality=85&downsize=30:*
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '1347'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"kg3mHhvXZ+hf2PdW8C4RFHbdR9s0koeR3coKCEnY9Lc"'}, {'Fastly-Io-Info': 'ifsz=657704 idim=500x502 ifmt=png ofsz=1347 odim=30x30 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': 'XN1Cu+licd/JpoItDzcUdme/4y0l1ak82pHvmT7/tvzaPzHPWzpQgaFFJA8nObpqVDOVehXu/so='}, {'X-Amz-Replication-Status': 'FAILED'}, {'X-Amz-Request-Id': '9PG5JFQBZ7PD4GJJ'}, {'X-Amz-Storage-Class': 'STANDARD_IA'}, {'X-Amz-Version-Id': 'O0S4R2Jo4rsTpx57pXPLhioeD3WytQ8g'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:18 GMT'}, {'Age': '4204912'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kiad7000064-IAD, cache-iad-kiad7000064-IAD, cache-maa10251-MAA'}, {'X-Cache': 'HIT, HIT, HIT'}, {'X-Cache-Hits': '1, 30771, 23'}, {'X-Timer': 'S1682319798.116840,VS0,VE0'}]
# Size/Weight: 1347 bytes
# ---
# Image URL: https://img.buzzfeed.com/buzzfeed-static/static/2023-04/5/8/campaign_images/80924ce3b002/do-you-think-any-of-these-12-bollywood-nepo-babie-3-1517-1680683021-9_dblbig.jpg?output-format=auto&output-quality=auto&resize=300:*;
# Headers Data:
# [{'Connection': 'keep-alive'}, {'Content-Length': '12078'}, {'Content-Type': 'image/jpeg'}, {'Etag': '"HbOy26i7BOVkjjQOoxFz47O9vXjPzoBnZa3CkPBIlBg"'}, {'Fastly-Io-Info': 'ifsz=257278 idim=625x415 ifmt=jpeg ofsz=12078 odim=300x199 ofmt=jpeg'}, {'Fastly-Stats': 'io=1'}, {'X-Amz-Id-2': '7MceB9QfAl4F63JXHqI5Rr9LdkYWM6A8JkY9uRWXjbrLvAHLsOT8nm7+H/yp4RWYLb6bXDpbFdI='}, {'X-Amz-Replication-Status': 'COMPLETED'}, {'X-Amz-Request-Id': 'AJ6WKZ59HWTP4E98'}, {'X-Amz-Server-Side-Encryption': 'AES256'}, {'X-Amz-Version-Id': 'bDITEg1mRZARMsYOju1mR4uWpWd9Lx47'}, {'Via': '1.1 varnish, 1.1 varnish, 1.1 varnish'}, {'Server': 'FastlyIO'}, {'Cache-Control': 'public, max-age=86400'}, {'Accept-Ranges': 'bytes'}, {'Date': 'Mon, 24 Apr 2023 07:03:18 GMT'}, {'Age': '1441871'}, {'Timing-Allow-Origin': '*'}, {'Access-Control-Allow-Origin': '*'}, {'X-Served-By': 'cache-iad-kiad7000070-IAD, cache-iad-kiad7000156-IAD, cache-maa10250-MAA'}, {'X-Cache': 'MISS, HIT, HIT'}, {'X-Cache-Hits': '0, 22, 2'}, {'X-Timer': 'S1682319798.191020,VS0,VE0'}, {'Vary': 'X-Image-Format-Optimization, X-Image-Quality-Optimization'}]
# Size/Weight: 12078 bytes (above 10KB)
# 5 images above 10KB retrieved. Exiting...
# Total number of images above 10KB: 5

# %%
pip install scrapy
# Out:
# Requirement already satisfied: scrapy in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (2.6.1)
# Requirement already satisfied: service-identity>=16.0.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: cssselect>=0.9.1 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.21.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: Twisted>=17.9.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (22.2.0)
# Requirement already satisfied: parsel>=1.5.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: protego>=0.1.15 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: tldextract in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (3.2.0)
# Requirement already satisfied: setuptools in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (61.2.0)
# Requirement already satisfied: queuelib>=1.4.2 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (1.5.0)
# Requirement already satisfied: itemadapter>=0.1.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: lxml>=3.5.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (4.8.0)
# Requirement already satisfied: cryptography>=2.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (3.4.8)
# Requirement already satisfied: zope.interface>=4.1.3 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (21.0.0)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: cffi>=1.12 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=2.0->scrapy) (1.15.0)
# Requirement already satisfied: pycparser in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.0->scrapy) (2.21)
# Requirement already satisfied: jmespath>=0.9.5 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: six>=1.6.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from parsel>=1.5.0->scrapy) (1.16.0)
# Requirement already satisfied: pyasn1 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: attrs>=16.0.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from service-identity>=16.0.0->scrapy) (21.4.0)
# Requirement already satisfied: pyasn1-modules in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: Automat>=0.8.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=17.9.0->scrapy) (20.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=17.9.0->scrapy) (4.1.1)
# Requirement already satisfied: hyperlink>=17.1.1 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=17.9.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=21.3.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=17.9.0->scrapy) (21.3.0)
# Requirement already satisfied: constantly>=15.1 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from Twisted>=17.9.0->scrapy) (15.1.0)
# Requirement already satisfied: idna>=2.5 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from hyperlink>=17.1.1->Twisted>=17.9.0->scrapy) (3.3)
# Requirement already satisfied: requests>=2.1.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from tldextract->scrapy) (2.27.1)
# Requirement already satisfied: requests-file>=1.4 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from tldextract->scrapy) (3.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import scrapy

class BuzzfeedSpider(scrapy.Spider):
    name = 'buzzfeed'
    start_urls = ['https://www.buzzfeed.com/in']
    num_images_above_10kb = 0

    def parse(self, response):
        # Extract all the <a> tags from the HTML
        a_tags = response.css('a')

        # Loop through each <a> tag and extract the href link
        for a_tag in a_tags:
            page_url = response.urljoin(a_tag.attrib['href'])
            self.logger.info(f'Page URL: {page_url}')

            # Make a request to the page URL
            yield scrapy.Request(page_url, callback=self.parse_page)

    def parse_page(self, response):
        # Extract all the <img> tags from the page HTML
        img_tags = response.css('img')

        # Loop through each <img> tag and extract the image src link
        for img_tag in img_tags:
            img_src = img_tag.attrib['src']
            img_url = response.urljoin(img_src)
            self.logger.info(f'Image URL: {img_url}')

            # Make a request to the image URL and retrieve the headers
            yield scrapy.Request(img_url, callback=self.parse_image,
                                 meta={'img_url': img_url})

    def parse_image(self, response):
        img_url = response.meta['img_url']
        headers = response.headers
        img_size = len(response.body)

        # Convert headers to array format
        headers_array = []
        for key, value in headers.items():
            headers_array.append({key.decode(): value.decode()})

        self.logger.info('Headers Data:')
        self.logger.info(headers_array)

        # Check the size/weight of the image
        if img_size > 10 * 1024:
            self.num_images_above_10kb += 1
            self.logger.info(f'Size/Weight: {img_size} bytes (above 10KB)')

            # Check if the desired count is reached
            if self.num_images_above_10kb == 5:
                self.logger.info('5 images above 10KB retrieved. Exiting...')
                raise scrapy.exceptions.CloseSpider('5 images above 10KB retrieved')

        else:
            self.logger.info(f'Size/Weight: {img_size} bytes')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import csv
import requests

def get_image_links(domain_url, output_path='output_images.csv', min_image_size_kb=300):
    driver = None

    try:
        # Set up Chrome options in headless mode
        chrome_options = Options()
        chrome_options.add_argument('--headless')
        chrome_options.add_argument('--disable-gpu')
        
        # Initialize Chrome WebDriver
        driver = webdriver.Chrome(options=chrome_options)

        # Fetch HTML content of the website using Selenium
        driver.get(domain_url)

        # Extract image links
        image_links = []
        for img_tag in driver.find_elements_by_tag_name('img'):
            img_url = img_tag.get_attribute('src')

            # Fetch image data and check size
            img_response = requests.get(img_url)
            img_size_kb = len(img_response.content) / 1024

            # If image size is not less than min_image_size_kb, add to the list
            if img_size_kb >= min_image_size_kb:
                image_links.append(img_url)
                print(f'Image URL (Size: {img_size_kb} KB): {img_url}')

        # Save the image URLs to CSV
        with open(output_path, 'w', newline='') as csvfile:
            csv_writer = csv.writer(csvfile)
            csv_writer.writerows([[url] for url in image_links])

    except Exception as e:
        print(f"Error: {e}")

    finally:
        if driver:
            # Close the WebDriver
            driver.quit()

# Example usage
domain_url = "https://flipkart.com"
get_image_links(domain_url)
# Out:
# Unable to obtain driver using Selenium Manager: Selenium Manager failed for: /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/macos/selenium-manager --browser chrome --output json.
# The chromedriver version cannot be discovered
# Error: Message: Selenium Manager failed for: /Users/rentsher/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/macos/selenium-manager --browser chrome --output json.
# The chromedriver version cannot be discovered
